# %%
# kaggel에서 데이터 다운 받기
# import opendatasets as od
# od.download('https://www.kaggle.com/datasets/uciml/student-alcohol-consumption?select=student-mat.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px # plotly라는 시각화라이브러리
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import missingno as msno # 결측치를 확인할 수 있는 라이브러리
import os
import sys
import warnings
import chart_studio
import chart_studio.plotly as py

warnings.filterwarnings('ignore')

# pandas 옵션 지정 -> 최대 컬럼 수 출력, float는 2자리까지 출력
pd.options.display.max_columns = 50
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # ****About Dataset****
#
# 1. school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# 2. sex - student's sex (binary: 'F' - female or 'M' - male)
# 3. age - student's age (numeric: from 15 to 22)
# 4. address - student's home address type (binary: 'U' - urban or 'R' - rural)
# 5. famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 6. Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 7. Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 8. Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 9. Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10. Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 11. reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 12. guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16. schoolsup - extra educational support (binary: yes or no)
# 17. famsup - family educational support (binary: yes or no)
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19. activities - extra-curricular activities (binary: yes or no)
# 20. nursery - attended nursery school (binary: yes or no)
# 21. higher - wants to take higher education (binary: yes or no)
# 22. internet - Internet access at home (binary: yes or no)
# 23. romantic - with a romantic relationship (binary: yes or no)
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
# 1. G1 - first period grade (numeric: from 0 to 20)
# 2. G2 - second period grade (numeric: from 0 to 20)
# 3. G3 - final grade (numeric: from 0 to 20, output target)

# %%
mat_df = pd.read_csv('~/git/hakcerton/data/student-alcohol-consumption/student-mat.csv')
pot_df = pd.read_csv('~/git/hakcerton/data/student-alcohol-consumption/student-por.csv')

# %% [markdown]
# mat_df.head()

# %%
# 복사본으로 카피
mat_eda_df = mat_df.copy()
pot_eda_df = pot_df.copy()

# %%
mat_eda_df.describe()
# Out:
#          age   Medu   Fedu  traveltime  studytime  failures  famrel  freetime  \
# count 395.00 395.00 395.00      395.00     395.00    395.00  395.00    395.00
# mean   16.70   2.75   2.52        1.45       2.04      0.33    3.94      3.24
# std     1.28   1.09   1.09        0.70       0.84      0.74    0.90      1.00
# min    15.00   0.00   0.00        1.00       1.00      0.00    1.00      1.00
# 25%    16.00   2.00   2.00        1.00       1.00      0.00    4.00      3.00
# 50%    17.00   3.00   2.00        1.00       2.00      0.00    4.00      3.00
# 75%    18.00   4.00   3.00        2.00       2.00      0.00    5.00      4.00
# max    22.00   4.00   4.00        4.00       4.00      3.00    5.00      5.00
#
#        goout   Dalc   Walc  health  absences     G1     G2     G3
# count 395.00 395.00 395.00  395.00    395.00 395.00 395.00 395.00
# mean    3.11   1.48   2.29    3.55      5.71  10.91  10.71  10.42
# std     1.11   0.89   1.29    1.39      8.00   3.32   3.76   4.58
# min     1.00   1.00   1.00    1.00      0.00   3.00   0.00   0.00
# 25%     2.00   1.00   1.00    3.00      0.00   8.00   9.00   8.00
# 50%     3.00   1.00   2.00    4.00      4.00  11.00  11.00  11.00
# 75%     4.00   2.00   3.00    5.00      8.00  13.00  13.00  14.00
# max     5.00   5.00   5.00    5.00     75.00  19.00  19.00  20.00

# %%
pot_eda_df.describe()
# Out:
#          age   Medu   Fedu  traveltime  studytime  failures  famrel  freetime  \
# count 649.00 649.00 649.00      649.00     649.00    649.00  649.00    649.00
# mean   16.74   2.51   2.31        1.57       1.93      0.22    3.93      3.18
# std     1.22   1.13   1.10        0.75       0.83      0.59    0.96      1.05
# min    15.00   0.00   0.00        1.00       1.00      0.00    1.00      1.00
# 25%    16.00   2.00   1.00        1.00       1.00      0.00    4.00      3.00
# 50%    17.00   2.00   2.00        1.00       2.00      0.00    4.00      3.00
# 75%    18.00   4.00   3.00        2.00       2.00      0.00    5.00      4.00
# max    22.00   4.00   4.00        4.00       4.00      3.00    5.00      5.00
#
#        goout   Dalc   Walc  health  absences     G1     G2     G3
# count 649.00 649.00 649.00  649.00    649.00 649.00 649.00 649.00
# mean    3.18   1.50   2.28    3.54      3.66  11.40  11.57  11.91
# std     1.18   0.92   1.28    1.45      4.64   2.75   2.91   3.23
# min     1.00   1.00   1.00    1.00      0.00   0.00   0.00   0.00
# 25%     2.00   1.00   1.00    2.00      0.00  10.00  10.00  10.00
# 50%     3.00   1.00   2.00    4.00      2.00  11.00  11.00  12.00
# 75%     4.00   2.00   3.00    5.00      6.00  13.00  13.00  14.00
# max     5.00   5.00   5.00    5.00     32.00  19.00  19.00  19.00

# %%
msno.matrix(df=mat_eda_df.iloc[:, :], color=(0.2, 0.2, 0.9), figsize=(15, 5))
# Out:
# <AxesSubplot: >

# %%
msno.matrix(df=pot_eda_df.iloc[:, :], color=(0.2, 0.2, 0.9), figsize=(15, 5))
# Out:
# <AxesSubplot: >

# %%
# 수학은 M 포트투칼 어는 P
mat_eda_df['subject'] = 'M'
pot_eda_df['subject'] = 'P'

# %%
concat_df = pd.concat([mat_eda_df, pot_eda_df], axis=0)

# %%
# Dalc 컬럼을  Dalc 와 Walc의 평균으로 재조정
concat_df['Malc'] = (concat_df['Dalc'] + concat_df['Walc']) / 2
concat_df.drop(['Dalc','Walc'], axis=1, inplace=True)

# %%
concat_df['Agrade'] = (concat_df['G1'] + concat_df['G2'] + concat_df['G3']) / 3
concat_df.drop(['G1', 'G2', 'G3'], axis=1, inplace=True)

# %%
concat_df.reset_index(inplace=True)
concat_df.drop('index', axis=1, inplace=True)

# %%
#concat_df.drop('level_0', axis=1, inplace=True)

# %%
concat_df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
#       reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0     course   mother           2          2         0       yes     no   no
# 1     course   father           1          2         0        no    yes   no
# 2      other   mother           1          2         3       yes     no  yes
# 3       home   mother           1          3         0        no    yes  yes
# 4       home   father           1          2         0        no    yes  yes
# ...      ...      ...         ...        ...       ...       ...    ...  ...
# 1039  course   mother           1          3         1        no     no   no
# 1040  course   mother           1          2         0        no    yes   no
# 1041  course   mother           2          2         0        no     no   no
# 1042  course   mother           2          1         0        no     no   no
# 1043  course   mother           3          1         0        no     no   no
#
#      activities nursery higher internet romantic  famrel  freetime  goout  \
# 0            no     yes    yes       no       no       4         3      4
# 1            no      no    yes      yes       no       5         3      3
# 2            no     yes    yes      yes       no       4         3      2
# 3           yes     yes    yes      yes      yes       3         2      2
# 4            no     yes    yes       no       no       4         3      2
# ...         ...     ...    ...      ...      ...     ...       ...    ...
# 1039        yes      no    yes      yes       no       5         4      2
# 1040         no     yes    yes      yes       no       4         3      4
# 1041        yes     yes    yes       no       no       1         1      1
# 1042         no      no    yes      yes       no       2         4      5
# 1043         no      no    yes      yes       no       4         4      1
#
#       health  absences subject  Malc  Agrade
# 0          3         6       M  1.00    5.67
# 1          3         4       M  1.00    5.33
# 2          3        10       M  2.50    8.33
# 3          5         2       M  1.00   14.67
# 4          5         4       M  1.50    8.67
# ...      ...       ...     ...   ...     ...
# 1039       5         4       P  1.50   10.33
# 1040       1         4       P  1.00   15.33
# 1041       5         6       P  1.00   10.67
# 1042       2         6       P  3.50   10.00
# 1043       5         4       P  3.50   10.67
#
# [1044 rows x 31 columns]

# %% [markdown]
# ## 상관관계

# %%
from dython.nominal import identify_nominal_columns
cat_featrues = identify_nominal_columns(mat_eda_df)
cat_featrues
# Out:
# ['school',
#  'sex',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'subject']

# %%
from dython.nominal import associations

# %% [markdown]
# ## 수학성적데이터 상관관계

# %%
# math 데이터 상관관계
complete_correlation = associations(mat_eda_df, filename='./corr_png/mat_correlation.png', figsize=(30, 30))

# %%
# Dalc과 feature 간의 상관관계
complete_correlation['corr'].sort_values(by='Dalc', ascending=False).style.background_gradient(cmap='coolwarm', axis=None).set_precision(3)
# Out:
# <style type="text/css">
# #T_58440_row0_col0, #T_58440_row0_col9, #T_58440_row1_col2, #T_58440_row1_col10, #T_58440_row2_col17, #T_58440_row5_col27, #T_58440_row8_col27, #T_58440_row9_col26, #T_58440_row9_col32, #T_58440_row10_col15, #T_58440_row10_col26, #T_58440_row13_col19, #T_58440_row15_col8, #T_58440_row18_col7, #T_58440_row19_col1, #T_58440_row24_col0, #T_58440_row24_col31, #T_58440_row27_col18, #T_58440_row29_col9, #T_58440_row30_col15 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_58440_row0_col1, #T_58440_row0_col25, #T_58440_row2_col26, #T_58440_row3_col26 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_58440_row0_col2, #T_58440_row2_col20, #T_58440_row5_col3, #T_58440_row8_col8, #T_58440_row8_col26, #T_58440_row10_col6, #T_58440_row12_col5, #T_58440_row13_col2, #T_58440_row14_col10, #T_58440_row17_col1, #T_58440_row23_col4, #T_58440_row25_col0, #T_58440_row26_col32, #T_58440_row29_col22 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T
{
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_58440_row0_col21, #T_58440_row1_col8, #T_58440_row1_col18, #T_58440_row2_col7, #T_58440_row3_col15, #T_58440_row4_col0, #T_58440_row4_col3, #T_58440_row6_col19, #T_58440_row8_col4, #T_58440_row8_col17, #T_58440_row10_col24, #T_58440_row11_col4, #T_58440_row11_col32, #T_58440_row12_col2, #T_58440_row12_col29, #T_58440_row13_col13, #T_58440_row13_col27, #T_58440_row14_col24, #T_58440_row15_col12, #T_58440_row16_col15, #T_58440_row18_col27, #T_58440_row19_col2, #T_58440_row20_col13, #T_58440_row21_col26, #

# %%
# 오름차순으로 정렬
corr_df = complete_correlation['corr'].sort_values(by='Dalc', ascending=False)

# %%
# 전체 상관관계 출력
px.bar(corr_df, x='Dalc')

# %% [markdown]
# ## 포르투칼어 데이터 상관관계

# %%
# 포르투갈 전체 상관관계 히트맵
complete_correlation = associations(pot_eda_df, filename='./corr_png/mat_correlation.png', figsize=(30, 30))

# %%
# Dalc와 featurer간의 상관관계
complete_correlation['corr'].sort_values(by='Dalc', ascending=False).style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style type="text/css">
# #T_76ed7_row0_col0, #T_76ed7_row0_col3, #T_76ed7_row0_col21, #T_76ed7_row2_col2, #T_76ed7_row2_col5, #T_76ed7_row3_col0, #T_76ed7_row3_col14, #T_76ed7_row6_col1, #T_76ed7_row8_col17, #T_76ed7_row10_col25, #T_76ed7_row11_col23, #T_76ed7_row12_col15, #T_76ed7_row12_col17, #T_76ed7_row13_col3, #T_76ed7_row14_col13, #T_76ed7_row15_col23, #T_76ed7_row16_col30, #T_76ed7_row16_col32, #T_76ed7_row17_col7, #T_76ed7_row18_col11, #T_76ed7_row18_col12, #T_76ed7_row18_col18, #T_76ed7_row19_col9, #T_76ed7_row19_col26, #T_76ed7_row20_col16, #T_76ed7_row20_col25, #T_76ed7_row20_col26, #T_76ed7_row21_col26, #T_76ed7_row22_col1, #T_76ed7_row23_col12, #T_76ed7_row24_col17, #T_76ed7_row25_col0, #T_76ed7_row26_col28, #T_76ed7_row29_col8, #T_76ed7_row29_col22, #T_76ed7_row30_col19, #T_76ed7_row32_col4, #T_76ed7_row33_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_76ed7_row0_col1, #T_76ed7_row2_col26, #T_76ed7_row20_col32, #T_76ed7_row33_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_76ed7_row0_col2, #T_76ed7_row2_col28, #T_76ed7_row6_col8, #T_76ed7_row6_col26, #T_76ed7_row8_col30, #T_76ed7_row11_col2, #T_76ed7_row17_col1, #T_76ed7_row20_col13, #T_76ed7_row21_col30, #T_76ed7_row25_col7, #T_76ed7_row26_col16, #T_76ed7_row30_col0, #T_76ed7_row32_col11, #T_76ed7_row32_col21 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T
T_76ed7_row24_col15, #T_76ed7_row24_col16, #T_76ed7_row24_col19, #T_76ed7_row24_col33, #T_76ed7_row25_col3, #T_76ed7_row25_col4, #T_76ed7_row25_col5, #T_76ed7_row25_col11, #T_76ed7_row25_col18, #T_76ed7_row25_col19, #T_76ed7_row25_col22, #T_76ed7_row25_col24, #T_76ed7_row25_col33, #T_76ed7_row26_col26, #T_76ed7_row26_col33, #T_76ed7_row27_col0, #T_76ed7_row27_col1, #T_76ed7_row27_col2, #T_76ed7_row27_col3, #T_76ed7_row27_col4, #T_76ed7_row27_col5, #T_76ed7_row27_col6, #T_76ed7_row27_col7, #T_76ed7_row27_col8, #T_76ed7_row27_col9, #T_76ed7_row27_col10, #T_76ed7_row27_col11, #T_76ed7_row27_col12, #T_76ed7_row27_col13, #T_76ed7_row27_col14, #T_76ed7_row27_col15, #T_76ed7_row27_col16, #T_76ed7_row27_col17, #T_76ed7_row27_col18, #T_76ed7_row27_col19, #T_76ed7_row27_col20, #T_76ed7_row27_col21, #T_76ed7_row27_col22, #T_76ed7_row27_col23, #T_76ed7_row27_col24, #T_76ed7_row27_col25, #T_76ed7_row27_col26, #T_76ed7_row27_col27, #T_76ed7_row27 ...
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_76ed7_row0_col8, #T_76ed7_row0_col9, #T_76ed7_row0_col12, #T_76ed7_row3_col21, #T_76ed7_row5_col7, #T_76ed7_row5_col8, #T_76ed7_row8_col12, #T_76ed7_row10_col21, #T_76ed7_row11_col10, #T_76ed7_row11_col26

# %%
# 상관관계 오름차순 정렬
corr_df = complete_correlation['corr'].sort_values(by='Dalc', ascending=False)

# %%
px.bar(corr_df, x='Dalc')

# %% [markdown]
# ## 수학성적 데이터와 포르투칼 데이터 합친 상관관계

# %%
complete_correlation = associations(concat_df, filename='./corr_png/concat_corr.png', figsize=(30, 30))

# %%
corr_df = complete_correlation['corr'].sort_values(by='Malc', ascending=False)

# %%
px.bar(corr_df, x='Malc')

# %%
complete_correlation = associations(concat_df, filename='./corr_png/concat_corr2.png', figsize=(30, 30))

# %%
complete_correlation['corr'].sort_values(by='Malc', ascending=False).style.background_gradient(cmap='coolwarm', axis=None).set_precision(3)
# Out:
# <style type="text/css">
# #T_70f84_row0_col0, #T_70f84_row0_col17, #T_70f84_row0_col21, #T_70f84_row1_col12, #T_70f84_row7_col12, #T_70f84_row7_col19, #T_70f84_row8_col26, #T_70f84_row9_col18, #T_70f84_row10_col2, #T_70f84_row10_col25, #T_70f84_row11_col14, #T_70f84_row12_col7, #T_70f84_row13_col2, #T_70f84_row13_col30, #T_70f84_row18_col29, #T_70f84_row19_col29, #T_70f84_row20_col13, #T_70f84_row20_col29, #T_70f84_row22_col7, #T_70f84_row23_col4, #T_70f84_row23_col5, #T_70f84_row26_col20, #T_70f84_row28_col30, #T_70f84_row29_col19, #T_70f84_row29_col23, #T_70f84_row30_col21 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_70f84_row0_col1, #T_70f84_row2_col29 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_70f84_row0_col2, #T_70f84_row0_col10, #T_70f84_row0_col14, #T_70f84_row5_col12, #T_70f84_row6_col29, #T_70f84_row7_col29, #T_70f84_row8_col29, #T_70f84_row9_col0, #T_70f84_row9_col11, #T_70f84_row10_col9, #T_70f84_row13_col11, #T_70f84_row14_col0, #T_70f84_row16_col7, #T_70f84_row16_col30, #T_70f84_row18_col15, #T_70f84_row18_col17, #T_70f84_row18_col20, #T_70f84_row19_col0, #T_70f84_row21_col19, #T_70f84_row21_col20, #T_70f84_row21_col22, #T_70f84_row23_col3, #T_70f84_row24_col11, #T_70f84_row29_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_70f84_row0_col3, #T_70f84_row0_col16, #T_70f84_row1_col27, #T_70f84_row2_col9, #T_70f84_row3_col6, #T_70f84_row3_col25, #T_70f84_row4_col21, #T_70f84_row5_col1, #T_70f84_row5_col3, #T_70f84_row5_col4, #T_70f84_row8_col3, #T_70f84_row12_col9, #T_70f84_row12_col16, #T_70f84_row13_col13, #T_70f84_row15_col4, #T_70f84_row15_col29, #T_70f84_row16_col9, #T_70f84_row16_col14, #T_70f84_row16_col29, #T_70f84_row17_col22, #T_70f84_row17_col23, #T_70f84_row20_col24, #T_70f84_row24_col8, #T_70f84_row25_col13, #T_70f84_row27_col27, #T_70f84_row28_col8, #T_70f84_row30_col19, #T_70f84_row30_col28 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_70f84_row0_col4, #T_70f84_row0_col19, #T_70f84_row3_col21, #T_70f84_row5_col14, #T_70f84_row6_col16, #T_70f84_row8_col9, #T_70f84_row12_col19, #T_70f84_row12_col29, #T_70f84_row13_col4, #T_70f84_row13_col29, #T_70f84_row15_col10, #T_70f84_row18_col18, #T_70f84_row20_col27, #T_70f84_row22_col18, #T_70f84_row23_col18, #T_70f84_row24_col30, #T_70f84_row26_col0, #T_70f84_row26_col5, #T_70f84_row26_col7, #T_70f84_row27_col13, #T_70f84_row29_col22, #T_70f84_row30_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_70f84_row0_col5, #T_70f84_row0_col11, #T_70f84_row1_col0, #T_70f84_row2_col2, #T_70f84_row2_col5, #T_70f84_row3_col3, #T_70f84_row4_col5, #T_70f84_row4_col17, #T_70f84_row7_col1, #T_70f84_row8_col17, #T_70f84_row10_col15, #T_70f84_row11_col7, #T_70f84_row12_col8, #T_70f84_row12_col13, #T_70f84_row14_col12, #T_70f84_row16_col13, #T_70f84_row16_col27, #T_70f84_row17_col4, #T_70f84_row17_col5, #T_70f84_row17_col13, #T_70f84_row18_col11, #T_70f84_row18_col23, #T_70f84_row18_col25, #T_70f84_row19_col11, #T_70f84_row19_col14, #T_70f84_row19_col24, #T_70f84_row19_col30, #T_70f84_row20_col22, #T_70f84_row21_col0, #T_70f84_row21_col17, #T_70f84_row21_col29, #T_70f84_row22_col1, #T_70f84_row22_col8, #T_70f84_row22_col22, #T_70f84_row22_col24, #T_70f84_row22_col29, #T_70f84_row23_col26, #T_70f84_row24_col5, #T_70f84_row24_col13, #T_70f84_row24_col21, #T_70f84_row28_col0, #T_70f84_row29_col17, #T_70f84_row30_col3, #T_70f84_row30_col4, #T_70f84_row30_col8, #T_70f84_row30_col22 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_70f84_row0_col6, #T_70f84_row27_col29 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_70f84_row0_col7, #T_70f84_row1_col17, #T_70f84_row1_col19, #T_70f84_row2_col27, #T_70f84_row3_col1, #T_70f84_row4_col19, #T_70f84_row4_col22, #T_70f84_row7_col4, #T_70f84_row10_col22, #T_70f84_row11_col5, #T_70f84_row11_col11, #T_70f84_row11_col18, #T_70f84_row12_col2, #T_70f84_row13_col24, #T_70f84_row13_col25, #T_70f84_row14_col28, #T_70f84_row16_col23, #T_70f84_row19_col23, #T_70f84_row19_col25, #T_70f84_row21_col26, #T_70f84_row22_col26, #T_70f84_row22_col30, #T_70f84_row23_col23, #T_70f84_row23_col29, #T_70f84_row24_col12, #T_70f84_row24_col24, #T_70f84_row25_col15, #T_70f84_row26_col26, #T_70f84_row27_col23, #T_70f84_row28_col3, #T_70f84_row28_col6, #T_70f84_row28_col7, #T_70f84_row28_col13, #T_70f84_row28_col17, #T_70f84_row29_col5, #T_70f84_row30_col23 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_70f84_row0_col8, #T_70f84_row1_col9, #T_70f84_row1_col15, #T_70f84_row2_col10, #T_70f84_row2_col21, #T_70f84_row2_col28, #T_70f84_row4_col11, #T_70f84_row5_col19, #T_70f84_row5_col25, #T_70f84_row6_col1, #T_70f84_row9_col21, #T_70f84_row11_col0, #T_70f84_row13_col9, #T_70f84_row14_col25, #T_70f84_row17_col29, #T_70f84_row18_col26, #T_70f84_row20_col1, #T_70f84_row20_col5, #T_70f84_row20_col20, #T_70f84_row21_col24, #T_70f84_row22_col21, #T_70f84_row24_col23, #T_70f84_row25_col1, #T_70f84_row26_col23, #T_70f84_row26_col30, #T_70f84_row28_col18, #T_70f84_row28_col22, #T_70f84_row29_col18 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_70f84_row0_col9, #T_70f84_row4_col18, #T_70f84_row5_col29, #T_70f84_row6_col20, #T_70f84_row9_col10, #T_70f84_row26_col24 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_70f84_row0_col12, #T_70f84_row2_col22, #T_70f84_row3_col14, #T_70f84_row4_col14, #T_70f84_row8_col24, #T_70f84_row8_col27, #T_70f84_row10_col29, #T_70f84_row11_col23, #T_70f84_row13_col7, #T_70f84_row14_col30, #T_70f84_row21_col30, #T_70f84_row23_col19, #T_70f84_row24_col1, #T_70f84_row25_col6, #T_70f84_row27_col28, #T_70f84_row28_col26, #T_70f84_row29_col11, #T_70f84_row29_col15 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_70f84_row0_col13, #T_70f84_row30_col29 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_70f84_row0_col15, #T_70f84_row1_col8, #T_70f84_row1_col14, #T_70f84_row1_col18, #T_70f84_row2_col23, #T_70f84_row3_col20, #T_70f84_row4_col9, #T_70f84_row5_col24, #T_70f84_row7_col18, #T_70f84_row8_col21, #T_70f84_row8_col22, #T_70f84_row8_col25, #T_70f84_row9_col27, #T_70f84_row14_col29, #T_70f84_row15_col21, #T_70f84_row17_col25, #T_70f84_row20_col14, #T_70f84_row20_col16, #T_70f84_row22_col6, #T_70f84_row24_col14, #T_70f84_row26_col2, #T_70f84_row26_col25, #T_70f84_row27_col5, #T_70f84_row28_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_70f84_row0_col18, #T_70f84_row2_col3, #T_70f84_row2_col17, #T_70f84_row2_col19, #T_70f84_row4_col6, #T_70f84_row5_col17, #T_70f84_row5_col22, #T_70f84_row5_col28, #T_70f84_row6_col4, #T_70f84_row6_col15, #T_70f84_row6_col19, #T_70f84_row9_col4, #T_70f84_row9_col5, #T_70f84_row11_col15, #T_70f84_row12_col10, #T_70f84_row12_col11, #T_70f84_row12_col17, #T_70f84_row12_col18, #T_70f84_row12_col20, #T_70f84_row12_col21, #T_70f84_row12_col22, #T_70f84_row12_col28, #T_70f84_row13_col0, #T_70f84_row13_col1, #T_70f84_row13_col3, #T_70f84_row13_col10, #T_70f84_row13_col15, #T_70f84_row13_col18, #T_70f84_row13_col21, #T_70f84_row13_col22, #T_70f84_row13_col28, #T_70f84_row14_col3, #T_70f84_row14_col5, #T_70f84_row14_col10, #T_70f84_row14_col17, #T_70f84_row14_col18, #T_70f84_row14_col19, #T_70f84_row14_col21, #T_70f84_row14_col26, #T_70f84_row15_col3, #T_70f84_row15_col5, #T_70f84_row15_col11, #T_70f84_row15_col18, #T_70f84_row15_col22, #T_70f84_row15_col28, #T_70f84_row15_col30, #T_70f84_row16_col1, #T_70f84_row16_col11, #T_70f84_row16_col15, #T_70f84_row16_col16, #T_70f84_row16_col18, #T_70f84_row16_col19, #T_70f84_row16_col22, #T_70f84_row18_col5, #T_70f84_row18_col19, #T_70f84_row19_col1, #T_70f84_row19_col4, #T_70f84_row19_col9, #T_70f84_row19_col15, #T_70f84_row19_col18, #T_70f84_row19_col22, #T_70f84_row20_col4, #T_70f84_row20_col11, #T_70f84_row20_col15, #T_70f84_row20_col19, #T_70f84_row21_col3, #T_70f84_row21_col4, #T_70f84_row21_col16, #T_70f84_row21_col18, #T_70f84_row21_col21, #T_70f84_row21_col28, #T_70f84_row22_col0, #T_70f84_row22_col15, #T_70f84_row22_col16, #T_70f84_row22_col20, #T_70f84_row22_col28, #T_70f84_row24_col3, #T_70f84_row24_col4, #T_70f84_ro

# %%
px.bar(corr_df, x='Malc')

# %%
# 상관계수를 절대값을 해준 후 데이터 프레임 만들기
abs_df = corr_df.Malc.abs().to_frame('corr_score').corr_score.nlargest(31).to_frame('score')

# %% [markdown]
# - 음의 상관관계도 포함

# %%
abs_df.reset_index(inplace=True)

# %%
choice_col_list_df = abs_df.head(17)

# %%
choice_col_list_df
# Out:
#          index  score
# 0         Malc   1.00
# 1        goout   0.37
# 2          sex   0.32
# 3    studytime   0.22
# 4       Agrade   0.15
# 5     absences   0.15
# 6     freetime   0.15
# 7         Fjob   0.13
# 8       reason   0.13
# 9          age   0.12
# 10    failures   0.12
# 11      higher   0.11
# 12  traveltime   0.10
# 13      famrel   0.10
# 14      health   0.10
# 15     famsize   0.09
# 16     nursery   0.09

# %% [markdown]
# ---

# %% [markdown]
# ### 최종 상관계수

# %%
Malc_df = corr_df[['Malc']]

# %%
Malc_df.reset_index(inplace=True)

# %%
pos_14_corr_df = Malc_df.head(14)

# %%
neg_4_corr_df = Malc_df.tail(3)

# %%
most_corr_df= pd.concat([pos_14_corr_df, neg_4_corr_df],axis=0)

# %%
most_corr_df.columns = ['features', 'score']

# %%
most_corr_df.reset_index(inplace=True)

# %%
most_corr_df.drop('index', inplace=True, axis=1)

# %%
most_corr_df
# Out:
#       features  score
# 0         Malc   1.00
# 1        goout   0.37
# 2          sex   0.32
# 3     absences   0.15
# 4     freetime   0.15
# 5         Fjob   0.13
# 6       reason   0.13
# 7          age   0.12
# 8     failures   0.12
# 9       higher   0.11
# 10  traveltime   0.10
# 11      health   0.10
# 12     famsize   0.09
# 13     nursery   0.09
# 14      famrel  -0.10
# 15      Agrade  -0.15
# 16   studytime  -0.22

# %% [markdown]
# ---

# %% [markdown]
# #### 일 소비량과 주말 소비량을 합쳐서 본 히트맵
# 학업에서 성공하는 비결은 술??????
# - 술 마시면 자신감이 배가 되어 시험을 잘 본다는 것이 학계의 정설!!
#
#
#
# - 술을 마신다고 해서 성적과 연관이 있을까? -> 결과적으로 술을 마시는 행위 자체가 일탈이라고 볼 수 있을까? -> 성적이 높다고 하여 모범생??????
# - 부모님의 교육 여부에 따라 술 소비량이 달라질까?
# - 나이가 많다고 해서 술을 많이 마실까?
# - 학교별로 나누어서 술 소비량이 성적에 미치는 것을 구별해야 할까?
# - 그럼 술을 많이 마시게 되는 요인이 무엇이 될까?
#   - 학교 환경
#   - 나가서 놀기
#   - 나이
#   - 부모님의 교육상태
#   - 여가시간
#   - 공부시간???
#   - 건강
#   - 결석
#   - 성적?
#   - 과목? 근데 수학을 선택했다면 누칼협아님?

# %% [markdown]
# - 용정 : 'failures', 'freetime', 'Fjob', AGrade
# - 종호 : 'studytime', 'sex', 'age', 'reason'
# - 정원 : 'goout', famrel, 'absences', 'health'

# %% [markdown]
# - Medu, famrel, AGrade, studytime

# %% [markdown]
# ## 범주형 변수 수치형변수로 변환하기

# %%
def init_mapping(data, col_ls):
    """_summary_

    Args:
        data (DataFrame): 변환하고자 하는 데이터 프레임
        col_name (list): 변환하고 하자는 데이터 프레임의 컬럼명을 리스트로 input
    """
    print('Start Mapping.......')
    print('-' * 50)
    for i in range(len(col_ls)):
        data_ls = data[col_ls[i]].unique()
        print('column name :', col_ls[i])
        print(data_ls)
        num = []
        num = [i for i in range(len(data_ls))] # 번호 생성
        ls = [(data_ls[i], num[i]) for i in range(len(data_ls))] # 해당 컬럼의 데이터 와 번호 리스트로 생성
        mapping = dict(ls) # dict로 만듬
        data[col_ls[i]] = data[col_ls[i]].apply(lambda x: mapping[x]) # mapping 적용

# %%
concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
#  19  nursery     1044 non-null   object
#  20  higher      1044 non-null   object
#  21  internet    1044 non-null   object
#  22  romantic    1044 non-null   object
#  23  famrel      1044 non-null   int64
#  24  freetime    1044 non-null   int64
#  25  goout       1044 non-null   int64
#  26  health      1044 non-null   int64
#  27  absences    1044 non-null   int64
#  28  subject     1044 non-null   object
#  29  Malc        1044 non-null   float64
#  30  Agrade      1044 non-null   float64
# dtypes: float64(2), int64(11), object(18)
# memory usage: 253.0+ KB

# %%
col_ls = [
    'school', 'sex', 'address', 'famsize', 
    'Pstatus', 'Mjob', 'Fjob', 'reason', 
    'guardian', 'schoolsup', 'famsup', 'paid', 
    'activities', 'nursery', 'higher', 
    'internet', 'romantic', 'subject'
    ]

# %%
init_mapping(concat_df, col_ls)
# Out:
# Start Mapping.......
# --------------------------------------------------
# column name : school
# ['GP' 'MS']
# column name : sex
# ['F' 'M']
# column name : address
# ['U' 'R']
# column name : famsize
# ['GT3' 'LE3']
# column name : Pstatus
# ['A' 'T']
# column name : Mjob
# ['at_home' 'health' 'other' 'services' 'teacher']
# column name : Fjob
# ['teacher' 'other' 'services' 'health' 'at_home']
# column name : reason
# ['course' 'other' 'home' 'reputation']
# column name : guardian
# ['mother' 'father' 'other']
# column name : schoolsup
# ['yes' 'no']
# column name : famsup
# ['no' 'yes']
# column name : paid
# ['no' 'yes']
# column name : activities
# ['no' 'yes']
# column name : nursery
# ['yes' 'no']
# column name : higher
# ['yes' 'no']
# column name : internet
# ['no' 'yes']
# column name : romantic
# ['no' 'yes']
# column name : subject
# ['M' 'P']

# %%
concat_df.head(10)
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0       0    0   18        0        0        0     4     4     0     0
# 1       0    0   17        0        0        1     1     1     0     1
# 2       0    0   15        0        1        1     1     1     0     1
# 3       0    0   15        0        0        1     4     2     1     2
# 4       0    0   16        0        0        1     3     3     2     1
# 5       0    1   16        0        1        1     4     3     3     1
# 6       0    1   16        0        1        1     2     2     2     1
# 7       0    0   17        0        0        0     4     4     2     0
# 8       0    1   15        0        1        0     3     2     3     1
# 9       0    1   15        0        0        1     3     4     2     1
#
#    reason  guardian  traveltime  studytime  failures  schoolsup  famsup  paid  \
# 0       0         0           2          2         0          0       0     0
# 1       0         1           1          2         0          1       1     0
# 2       1         0           1          2         3          0       0     1
# 3       2         0           1          3         0          1       1     1
# 4       2         1           1          2         0          1       1     1
# 5       3         0           1          2         0          1       1     1
# 6       2         0           1          2         0          1       0     0
# 7       2         0           2          2         0          0       1     0
# 8       2         0           1          2         0          1       1     1
# 9       2         0           1          2         0          1       1     1
#
#    activities  nursery  higher  internet  romantic  famrel  freetime  goout  \
# 0           0        0       0         0         0       4         3      4
# 1           0        1       0         1         0       5         3      3
# 2           0        0       0         1         0       4         3      2
# 3           1        0       0         1         1       3         2      2
# 4           0        0       0         0         0       4         3      2
# 5           1        0       0         1         0       5         4      2
# 6           0        0       0         1         0       4         4      4
# 7           0        0       0         0         0       4         1      4
# 8           0        0       0         1         0       4         2      2
# 9           1        0       0         1         0       5         5      1
#
#    health  absences  subject  Malc  Agrade
# 0       3         6        0  1.00    5.67
# 1       3         4        0  1.00    5.33
# 2       3        10        0  2.50    8.33
# 3       5         2        0  1.00   14.67
# 4       5         4        0  1.50    8.67
# 5       5        10        0  1.50   15.00
# 6       3         0        0  1.00   11.67
# 7       1         6        0  1.00    5.67
# 8       1         0        0  1.00   17.67
# 9       5         0        0  1.00   14.67

# %%
# concat_df.to_csv('~/git/hakcerton/data/preprocessing/final_data.csv', index=False)
