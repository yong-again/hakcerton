# %%
# kaggel에서 데이터 다운 받기
# import opendatasets as od
# od.download('https://www.kaggle.com/datasets/uciml/student-alcohol-consumption?select=student-mat.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px # plotly라는 시각화라이브러리
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import missingno as msno # 결측치를 확인할 수 있는 라이브러리
import os
import sys
import warnings
import chart_studio
import chart_studio.plotly as py

warnings.filterwarnings('ignore')

# pandas 옵션 지정 -> 최대 컬럼 수 출력, float는 2자리까지 출력
pd.options.display.max_columns = 50
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # ****About Dataset****
#
# 1. school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# 2. sex - student's sex (binary: 'F' - female or 'M' - male)
# 3. age - student's age (numeric: from 15 to 22)
# 4. address - student's home address type (binary: 'U' - urban or 'R' - rural)
# 5. famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# 6. Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# 7. Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 8. Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# 9. Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 10. Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# 11. reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# 12. guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# 16. schoolsup - extra educational support (binary: yes or no)
# 17. famsup - family educational support (binary: yes or no)
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# 19. activities - extra-curricular activities (binary: yes or no)
# 20. nursery - attended nursery school (binary: yes or no)
# 21. higher - wants to take higher education (binary: yes or no)
# 22. internet - Internet access at home (binary: yes or no)
# 23. romantic - with a romantic relationship (binary: yes or no)
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
# 1. G1 - first period grade (numeric: from 0 to 20)
# 2. G2 - second period grade (numeric: from 0 to 20)
# 3. G3 - final grade (numeric: from 0 to 20, output target)

# %%
mat_df = pd.read_csv('~/desktop/git/hakcerton/data/student-alcohol-consumption/student-mat.csv')
pot_df = pd.read_csv('~/desktop/git/hakcerton/data/student-alcohol-consumption/student-por.csv')

# %% [markdown]
# mat_df.head()

# %%
# 복사본으로 카피
mat_eda_df = mat_df.copy()
pot_eda_df = pot_df.copy()

# %%
mat_eda_df.describe()
# Out:
#          age   Medu   Fedu  traveltime  studytime  failures  famrel  freetime  \
# count 395.00 395.00 395.00      395.00     395.00    395.00  395.00    395.00
# mean   16.70   2.75   2.52        1.45       2.04      0.33    3.94      3.24
# std     1.28   1.09   1.09        0.70       0.84      0.74    0.90      1.00
# min    15.00   0.00   0.00        1.00       1.00      0.00    1.00      1.00
# 25%    16.00   2.00   2.00        1.00       1.00      0.00    4.00      3.00
# 50%    17.00   3.00   2.00        1.00       2.00      0.00    4.00      3.00
# 75%    18.00   4.00   3.00        2.00       2.00      0.00    5.00      4.00
# max    22.00   4.00   4.00        4.00       4.00      3.00    5.00      5.00
#
#        goout   Dalc   Walc  health  absences     G1     G2     G3
# count 395.00 395.00 395.00  395.00    395.00 395.00 395.00 395.00
# mean    3.11   1.48   2.29    3.55      5.71  10.91  10.71  10.42
# std     1.11   0.89   1.29    1.39      8.00   3.32   3.76   4.58
# min     1.00   1.00   1.00    1.00      0.00   3.00   0.00   0.00
# 25%     2.00   1.00   1.00    3.00      0.00   8.00   9.00   8.00
# 50%     3.00   1.00   2.00    4.00      4.00  11.00  11.00  11.00
# 75%     4.00   2.00   3.00    5.00      8.00  13.00  13.00  14.00
# max     5.00   5.00   5.00    5.00     75.00  19.00  19.00  20.00

# %%
pot_eda_df.describe()
# Out:
#          age   Medu   Fedu  traveltime  studytime  failures  famrel  freetime  \
# count 649.00 649.00 649.00      649.00     649.00    649.00  649.00    649.00
# mean   16.74   2.51   2.31        1.57       1.93      0.22    3.93      3.18
# std     1.22   1.13   1.10        0.75       0.83      0.59    0.96      1.05
# min    15.00   0.00   0.00        1.00       1.00      0.00    1.00      1.00
# 25%    16.00   2.00   1.00        1.00       1.00      0.00    4.00      3.00
# 50%    17.00   2.00   2.00        1.00       2.00      0.00    4.00      3.00
# 75%    18.00   4.00   3.00        2.00       2.00      0.00    5.00      4.00
# max    22.00   4.00   4.00        4.00       4.00      3.00    5.00      5.00
#
#        goout   Dalc   Walc  health  absences     G1     G2     G3
# count 649.00 649.00 649.00  649.00    649.00 649.00 649.00 649.00
# mean    3.18   1.50   2.28    3.54      3.66  11.40  11.57  11.91
# std     1.18   0.92   1.28    1.45      4.64   2.75   2.91   3.23
# min     1.00   1.00   1.00    1.00      0.00   0.00   0.00   0.00
# 25%     2.00   1.00   1.00    2.00      0.00  10.00  10.00  10.00
# 50%     3.00   1.00   2.00    4.00      2.00  11.00  11.00  12.00
# 75%     4.00   2.00   3.00    5.00      6.00  13.00  13.00  14.00
# max     5.00   5.00   5.00    5.00     32.00  19.00  19.00  19.00

# %%
msno.matrix(df=mat_eda_df.iloc[:, :], color=(0.2, 0.2, 0.9), figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df=pot_eda_df.iloc[:, :], color=(0.2, 0.2, 0.9), figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
# 수학은 M 포트투칼 어는 P
mat_eda_df['subject'] = 'M'
pot_eda_df['subject'] = 'P'

# %%
concat_df = pd.concat([mat_eda_df, pot_eda_df], axis=0)

# %%
# Dalc 컬럼을  Dalc 와 Walc의 평균으로 재조정
concat_df['Malc'] = (concat_df['Dalc'] + concat_df['Walc']) / 2
concat_df.drop(['Dalc','Walc'], axis=1, inplace=True)

# %%
concat_df['Agrade'] = (concat_df['G1'] + concat_df['G2'] + concat_df['G3']) / 3
concat_df.drop(['G1', 'G2', 'G3'], axis=1, inplace=True)

# %%
concat_df.reset_index(inplace=True)
concat_df.drop('index', axis=1, inplace=True)

# %%
#concat_df.drop('level_0', axis=1, inplace=True)

# %%
concat_df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
#       reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0     course   mother           2          2         0       yes     no   no
# 1     course   father           1          2         0        no    yes   no
# 2      other   mother           1          2         3       yes     no  yes
# 3       home   mother           1          3         0        no    yes  yes
# 4       home   father           1          2         0        no    yes  yes
# ...      ...      ...         ...        ...       ...       ...    ...  ...
# 1039  course   mother           1          3         1        no     no   no
# 1040  course   mother           1          2         0        no    yes   no
# 1041  course   mother           2          2         0        no     no   no
# 1042  course   mother           2          1         0        no     no   no
# 1043  course   mother           3          1         0        no     no   no
#
#      activities nursery higher internet romantic  famrel  freetime  goout  \
# 0            no     yes    yes       no       no       4         3      4
# 1            no      no    yes      yes       no       5         3      3
# 2            no     yes    yes      yes       no       4         3      2
# 3           yes     yes    yes      yes      yes       3         2      2
# 4            no     yes    yes       no       no       4         3      2
# ...         ...     ...    ...      ...      ...     ...       ...    ...
# 1039        yes      no    yes      yes       no       5         4      2
# 1040         no     yes    yes      yes       no       4         3      4
# 1041        yes     yes    yes       no       no       1         1      1
# 1042         no      no    yes      yes       no       2         4      5
# 1043         no      no    yes      yes       no       4         4      1
#
#       health  absences subject  Malc  Agrade
# 0          3         6       M  1.00    5.67
# 1          3         4       M  1.00    5.33
# 2          3        10       M  2.50    8.33
# 3          5         2       M  1.00   14.67
# 4          5         4       M  1.50    8.67
# ...      ...       ...     ...   ...     ...
# 1039       5         4       P  1.50   10.33
# 1040       1         4       P  1.00   15.33
# 1041       5         6       P  1.00   10.67
# 1042       2         6       P  3.50   10.00
# 1043       5         4       P  3.50   10.67
#
# [1044 rows x 31 columns]

# %%
# 성별 관련 analysis 추가
concat_df_sex = pd.concat([mat_eda_df, pot_eda_df], axis=0)
concat_df_sex['Malc'] = (concat_df_sex['Dalc'] + concat_df_sex['Walc']) / 2

# %% [markdown]
# ## 상관관계

# %%
from dython.nominal import identify_nominal_columns
cat_featrues = identify_nominal_columns(mat_eda_df)
cat_featrues
# Out:
# ['school',
#  'sex',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'subject']

# %%
from dython.nominal import associations

# %% [markdown]
# ## 수학성적데이터 상관관계

# %%
# math 데이터 상관관계
complete_correlation = associations(mat_eda_df, filename='./corr_png/mat_correlation.png', figsize=(30, 30))

# %%
# Dalc과 feature 간의 상관관계
complete_correlation['corr'].sort_values(by='Dalc', ascending=False).style.background_gradient(cmap='coolwarm', axis=None).set_precision(3)
# Out:
# <style type="text/css">
# #T_d638b_row0_col0, #T_d638b_row0_col9, #T_d638b_row1_col2, #T_d638b_row1_col10, #T_d638b_row2_col17, #T_d638b_row5_col27, #T_d638b_row8_col27, #T_d638b_row9_col26, #T_d638b_row9_col32, #T_d638b_row10_col15, #T_d638b_row10_col26, #T_d638b_row13_col19, #T_d638b_row15_col8, #T_d638b_row18_col7, #T_d638b_row19_col1, #T_d638b_row24_col0, #T_d638b_row24_col31, #T_d638b_row27_col18, #T_d638b_row29_col9, #T_d638b_row30_col15 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_d638b_row0_col1, #T_d638b_row0_col25, #T_d638b_row2_col26, #T_d638b_row3_col26 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_d638b_row0_col2, #T_d638b_row2_col20, #T_d638b_row5_col3, #T_d638b_row8_col8, #T_d638b_row8_col26, #T_d638b_row10_col6, #T_d638b_row12_col5, #T_d638b_row13_col2, #T_d638b_row14_col10, #T_d638b_row17_col1, #T_d638b_row23_col4, #T_d638b_row25_col0, #T_d638b_row26_col32, #T_d638b_row29_col22 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_d638b_row0_col3, #T_d638b_row0_col8, #T_d638b_row1_col28, #T_d638b_row2_col30, #T_d638b_row4_col14, #T_d638b_row5_col8, #T_d638b_row5_col16, #T_d638b_row6_col14, #T_d638b_row7_col12, #T_d638b_row7_col22, #T_d638b_row7_col24, #T_d638b_row9_col23, #T_d638b_row12_col16, #T_d638b_row13_col10, #T_d638b_row13_col26, #T_d638b_row14_col26, #T_d638b_row16_col23, #T_d638b_row16_col27, #T_d638b_row22_col4, #T_d638b_row22_col10, #T_d638b_row26_col14, #T_d638b_row31_col9, #T_d638b_row31_col28, #T_d638b_row32_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_d638b_row0_col4, #T_d638b_row1_col3, #T_d638b_row1_col19, #T_d638b_row1_col20, #T_d638b_row5_col18, #T_d638b_row7_col19, #T_d638b_row10_col18, #T_d638b_row11_col6, #T_d638b_row11_col21, #T_d638b_row12_col26, #T_d638b_row14_col27, #T_d638b_row15_col14, #T_d638b_row15_col27, #T_d638b_row17_col27, #T_d638b_row18_col0, #T_d638b_row18_col10, #T_d638b_row21_col29, #T_d638b_row21_col32, #T_d638b_row25_col29, #T_d638b_row29_col13, #T_d638b_row29_col21, #T_d638b_row33_col32 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_d638b_row0_col5, #T_d638b_row0_col16, #T_d638b_row2_col2, #T_d638b_row3_col12, #T_d638b_row4_col6, #T_d638b_row5_col23, #T_d638b_row6_col5, #T_d638b_row6_col25, #T_d638b_row8_col1, #T_d638b_row8_col5, #T_d638b_row10_col11, #T_d638b_row11_col3, #T_d638b_row12_col28, #T_d638b_row14_col29, #T_d638b_row16_col4, #T_d638b_row16_col16, #T_d638b_row20_col0, #T_d638b_row21_col5, #T_d638b_row21_col23, #T_d638b_row22_col26, #T_d638b_row22_col28, #T_d638b_row23_col2, #T_d638b_row23_col12, #T_d638b_row23_col21, #T_d638b_row23_col26, #T_d638b_row25_col24, #T_d638b_row31_col10, #T_d638b_row31_col21 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_d638b_row0_col6, #T_d638b_row0_col15, #T_d638b_row2_col11, #T_d638b_row4_col4, #T_d638b_row6_col22, #T_d638b_row11_col19, #T_d638b_row12_col24, #T_d638b_row14_col13, #T_d638b_row15_col28, #T_d638b_row15_col29, #T_d638b_row16_col19, #T_d638b_row20_col1, #T_d638b_row22_col23, #T_d638b_row24_col26, #T_d638b_row25_col26, #T_d638b_row26_col12, #T_d638b_row31_col16, #T_d638b_row31_col30, #T_d638b_row32_col23, #T_d638b_row33_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_d638b_row0_col7, #T_d638b_row1_col5, #T_d638b_row3_col5, #T_d638b_row3_col19, #T_d638b_row6_col16, #T_d638b_row7_col5, #T_d638b_row15_col23, #T_d638b_row15_col25, #T_d638b_row22_col12, #T_d638b_row23_col14, #T_d638b_row23_col25, #T_d638b_row23_col27, #T_d638b_row24_col23, #T_d638b_row27_col26, #T_d638b_row31_col15, #T_d638b_row31_col19 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_d638b_row0_col10, #T_d638b_row5_col26, #T_d638b_row17_col30, #T_d638b_row17_col31, #T_d638b_row30_col20, #T_d638b_row32_col20 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_d638b_row0_col11, #T_d638b_row3_col10, #T_d638b_row4_col21, #T_d638b_row5_col7, #T_d638b_row5_col25, #T_d638b_row8_col23, #T_d638b_row10_col31, #T_d638b_row15_col32, #T_d638b_row18_col31, #T_d638b_row20_col23, #T_d638b_row20_col26, #T_d638b_row21_col24, #T_d638b_row24_col22, #T_d638b_row26_col13, #T_d638b_row26_col15, #T_d638b_row27_col10, #T_d638b_row29_col19, #T_d638b_row29_col23, #T_d638b_row30_col0, #T_d638b_row30_col18, #T_d638b_row31_col2, #T_d638b_row31_col11, #T_d638b_row31_col32, #T_d638b_row33_col22 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_d638b_row0_col12, #T_d638b_row0_col14, #T_d638b_row1_col12, #T_d638b_row1_col29, #T_d638b_row2_col16, #T_d638b_row5_col20, #T_d638b_row6_col9, #T_d638b_row6_col26, #T_d638b_row6_col27, #T_d638b_row7_col26, #T_d638b_row9_col12, #T_d638b_row9_col13, #T_d638b_row11_col5, #T_d638b_row11_col27, #T_d638b_row14_col6, #T_d638b_row17_col10, #T_d638b_row19_col21, #T_d638b_row20_col6, #T_d638b_row20_col7, #T_d638b_row21_col17, #T_d638b_row22_col1, #T_d638b_row23_col29, #T_d638b_row25_col3, #T_d638b_row25_col11, #T_d638b_row27_col11, #T_d638b_row30_col13, #T_d638b_row33_col9, #T_d638b_row33_col31 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_d638b_row0_col13, #T_d638b_row33_col26 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_d638b_row0_col17, #T_d638b_row1_col17, #T_d638b_row2_col12, #T_d638b_row3_col6, #T_d638b_row3_col9, #T_d638b_row3_col23, #T_d638b_row4_col17, #T_d638b_row4_col20, #T_d638b_row6_col1, #T_d638b_row6_col4, #T_d638b_row6_col11, #T_d638b_row7_col0, #T_d638b_row7_col21, #T_d638b_row7_col29, #T_d638b_row9_col25, #T_d638b_row10_col14, #T_d638b_row10_col19, #T_d638b_row11_col14, #T_d638b_row12_col12, #T_d638b_row15_col0, #T_d638b_row15_col5, #T_d638b_row17_col24, #T_d638b_row19_col24, #T_d638b_row19_col26, #T_d638b_row19_col27, #T_d638b_row20_col12, #T_d638b_row21_col13, #T_d638b_row21_col14, #T_d638b_row21_col22, #T_d638b_row23_col19, #T_d638b_row25_col25, #T_d638b_row26_col21, #T_d638b_row26_col23, #T_d638b_row31_col22, #T_d638b_row31_col25, #T_d638b_row33_col21 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_d638b_row0_col18, #T_d638b_row0_col20, #T_d638b_row1_col0, #T_d638b_row2_col4, #T_d638b_row2_col10, #T_d638b_row2_col29, #T_d638b_row3_col3, #T_d638b_row4_col11, #T_d638b_row5_col1, #T_d638b_row6_col17, #T_d638b_row7_col18, #T_d638b_row7_col28, #T_d638b_row9_col19, #T_d638b_row10_col27, #T_d638b_row11_col1, #T_d638b_row12_col1, #T_d638b_row14_col25, #T_d638b_row14_col30, #T_d638b_row15_col9, #T_d638b_row15_col30, #T_d638b_row15_col31, #T_d638b_row16_col11, #T_d638b_row16_col14, #T_d638b_row17_col18, #T_d638b_row17_col26, #T_d638b_row18_col14, #T_d638b_row18_col20, #T_d638b_row18_col26, #T_d638b_row19_col12, #T_d638b_row20_col24, #T_d638b_row20_col28, #T_d638b_row25_col13, #T_d638b_row30_col19, #T_d638b_row32_col3, #T_d638b_row32_col19, #T_d638b_row33_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_d638b_row0_col19, #T_d638b_row2_col22, #T_d638b_row3_col11, #T_d638b_row6_col20, #T_d638b_row9_col16, #T_d638b_row12_col19, #T_d638b_row12_col31, #T_d638b_row12_col32, #T_d638b_row13_col11, #T_d638b_row13_col23, #T_d638b_row15_col4, #T_d638b_row15_col13, #T_d638b_row15_col17, #T_d638b_row15_col26, #T_d638b_row17_col12, #T_d638b_row19_col19, #T_d638b_row20_col5, #T_d638b_row20_col8, #T_d638b_row20_col25, #T_d638b_row21_col16, #T_d638b_row22_col9, #T_d638b_row22_col15, #T_d638b_row22_col21, #T_d638b_row22_col30, #T_d638b_row23_col11, #T_d638b_row24_col16, #T_d638b_row24_col32, #T_d638b_row26_col1, #T_d638b_row29_col4, #T_d638b_row29_col15, #T_d638b_row30_col4, #T_d638b_row31_col8, #T_d638b_row32_col16, #T_d638b_row33_col19 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_d638b_row0_col21, #T_d638b_row1_col8, #T_d638b_row1_col18, #T_d638b_row2_col7, #T_d638b_row3_col15, #T_d638b_row4_col0, #T_d638b_row4_col3, #T_d638b_row6_col19, #T_d638b_row8_col4, #T_d638b_row8_col17, #T_d638b_row10_col24, #T_d638b_row11_col4, #T_d638b_row11_col32, #T_d638b_row12_col2, #T_d638b_row12_col29, #T_d638b_row13_col13, #T_d638b_row13_col27, #T_d638b_row14_col24, #T_d638b_row15_col12, #T_d638b_row16_col15, #T_d638b_row18_col27, #T_d638b_row19_col2, #T_d638b_row20_col13, #T_d638b_row21_col26, #

# %%
# 오름차순으로 정렬
corr_df = complete_correlation['corr'].sort_values(by='Dalc', ascending=False)

# %%
# 전체 상관관계 출력
px.bar(corr_df, x='Dalc')

# %% [markdown]
# ## 포르투칼어 데이터 상관관계

# %%
# 포르투갈 전체 상관관계 히트맵
complete_correlation = associations(pot_eda_df, filename='./corr_png/mat_correlation.png', figsize=(30, 30))

# %%
# Dalc와 featurer간의 상관관계
complete_correlation['corr'].sort_values(by='Dalc', ascending=False).style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style type="text/css">
# #T_00ea5_row0_col0, #T_00ea5_row0_col3, #T_00ea5_row0_col21, #T_00ea5_row2_col2, #T_00ea5_row2_col5, #T_00ea5_row3_col0, #T_00ea5_row3_col14, #T_00ea5_row6_col1, #T_00ea5_row8_col17, #T_00ea5_row10_col25, #T_00ea5_row11_col23, #T_00ea5_row12_col15, #T_00ea5_row12_col17, #T_00ea5_row13_col3, #T_00ea5_row14_col13, #T_00ea5_row15_col23, #T_00ea5_row16_col30, #T_00ea5_row16_col32, #T_00ea5_row17_col7, #T_00ea5_row18_col11, #T_00ea5_row18_col12, #T_00ea5_row18_col18, #T_00ea5_row19_col9, #T_00ea5_row19_col26, #T_00ea5_row20_col16, #T_00ea5_row20_col25, #T_00ea5_row20_col26, #T_00ea5_row21_col26, #T_00ea5_row22_col1, #T_00ea5_row23_col12, #T_00ea5_row24_col17, #T_00ea5_row25_col0, #T_00ea5_row26_col28, #T_00ea5_row29_col8, #T_00ea5_row29_col22, #T_00ea5_row30_col19, #T_00ea5_row32_col4, #T_00ea5_row33_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_00ea5_row0_col1, #T_00ea5_row2_col26, #T_00ea5_row20_col32, #T_00ea5_row33_col0 {
, #T_00ea5_row20_col5, #T_00ea5_row20_col17, #T_00ea5_row20_col19, #T_00ea5_row20_col33, #T_00ea5_row21_col4, #T_00ea5_row21_col11, #T_00ea5_row21_col15, #T_00ea5_row21_col17, #T_00ea5_row21_col19, #T_00ea5_row21_col22, #T_00ea5_row21_col33, #T_00ea5_row22_col0, #T_00ea5_row22_col8, #T_00ea5_row22_col15, #T_00ea5_row22_col16, #T_00ea5_row22_col17, #T_00ea5_row22_col19, #T_00ea5_row22_col20, #T_00ea5_row22_col32, #T_00ea5_row22_col33, #T_00ea5_row23_col3, #T_00ea5_row23_col5, #T_00ea5_row23_col11, #T_00ea5_row23_col14, #T_00ea5_row23_col17, #T_00ea5_row23_col18, #T_00ea5_row23_col19, #T_00ea5_row23_col21, #T_00ea5_row23_col33, #T_00ea5_row24_col3, #T_00ea5_row24_col4, #T_00ea5_row24_col9, #T_00ea5_row24_col11, #T_00ea5_row24_col14, #T_00ea5_row24_col15, #T_00ea5_row24_col16, #T_00ea5_row24_col19, #T_00ea5_row24_col33, #T_00ea5_row25_col3, #T_00ea5_row25_col4, #T_00ea5_row25_col5, #T_00ea5_row25_col11, #T_00ea5_row25_col18, #T_00ea5_row25_col19, #T_00ea5_row25_col22, #T_00ea5_row25_col24, #T_00ea5_row25_col33, #T_00ea5_row26_col26, #T_00ea5_row26_col33, #T_00ea5_row27_col0, #T_00ea5_row27_col1, #T_00ea5_row27_col2, #T_00ea5_row27_col3, #T_00ea5_row27_col4, #T_00ea5_row27_col5, #T_00ea5_row27_col6, #T_00ea5_row27_col7, #T_00ea5_row27_col8, #T_00ea5_row27_col9, #T_00ea5_row27_col10, #T_00ea5_row27_col11, #T_00ea5_row27_col12, #T_00ea5_row27_col13, #T_00ea5_row27_col14, #T_00ea5_row27_col15, #T_00ea5_row27_col16, #T_00ea5_row27_col17, #T_00ea5_row27_col18, #T_00ea5_row27_col19, #T_00ea5_row27_col20, #T_00ea5_row27_col21, #T_00ea5_row27_col22, #T_00ea5_row27_col23, #T_00ea5_row27_col24, #T_00ea5_row27_col25, #T_00ea5_row27_col26, #T_00ea5_row27_col27, #T_00ea5_row27 ...
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_00ea5_row0_col8, #T_00ea5_row0_col9, #T_00ea5_row0_col12, #T_00ea5_row3_col21, #T_00ea5_row5_col7, #T_00ea5_row5_col8, #T_00ea5_row8_col12, #T_00ea5_row10_col21, #T_00ea5_row11_col10, #T_00ea5_row11_col26

# %%
# 상관관계 오름차순 정렬
corr_df = complete_correlation['corr'].sort_values(by='Dalc', ascending=False)

# %%
px.bar(corr_df, x='Dalc')

# %% [markdown]
# ## 수학성적 데이터와 포르투칼 데이터 합친 상관관계

# %%
complete_correlation = associations(concat_df, filename='./corr_png/concat_corr.png', figsize=(30, 30))

# %%
corr_df = complete_correlation['corr'].sort_values(by='Malc', ascending=False)

# %%
px.bar(corr_df, x='Malc')

# %%
complete_correlation = associations(concat_df, filename='./corr_png/concat_corr2.png', figsize=(30, 30))

# %%
complete_correlation['corr'].sort_values(by='Malc', ascending=False).style.background_gradient(cmap='coolwarm', axis=None).set_precision(3)
_col22, #T_f9b4a_row12_col28, #T_f9b4a_row13_col0, #T_f9b4a_row13_col1, #T_f9b4a_row13_col3, #T_f9b4a_row13_col10, #T_f9b4a_row13_col15, #T_f9b4a_row13_col18, #T_f9b4a_row13_col21, #T_f9b4a_row13_col22, #T_f9b4a_row13_col28, #T_f9b4a_row14_col3, #T_f9b4a_row14_col5, #T_f9b4a_row14_col10, #T_f9b4a_row14_col17, #T_f9b4a_row14_col18, #T_f9b4a_row14_col19, #T_f9b4a_row14_col21, #T_f9b4a_row14_col26, #T_f9b4a_row15_col3, #T_f9b4a_row15_col5, #T_f9b4a_row15_col11, #T_f9b4a_row15_col18, #T_f9b4a_row15_col22, #T_f9b4a_row15_col28, #T_f9b4a_row15_col30, #T_f9b4a_row16_col1, #T_f9b4a_row16_col11, #T_f9b4a_row16_col15, #T_f9b4a_row16_col16, #T_f9b4a_row16_col18, #T_f9b4a_row16_col19, #T_f9b4a_row16_col22, #T_f9b4a_row18_col5, #T_f9b4a_row18_col19, #T_f9b4a_row19_col1, #T_f9b4a_row19_col4, #T_f9b4a_row19_col9, #T_f9b4a_row19_col15, #T_f9b4a_row19_col18, #T_f9b4a_row19_col22, #T_f9b4a_row20_col4, #T_f9b4a_row20_col11, #T_f9b4a_row20_col15, #T_f9b4a_row20_col19, #T_f9b4a_row21_col3, #T_f9b4a_row21_col4, #T_f9b4a_row21_col16, #T_f9b4a_row21_col18, #T_f9b4a_row21_col21, #T_f9b4a_row21_col28, #T_f9b4a_row22_col0, #T_f9b4a_row22_col15, #T_f9b4a_row22_col16, #T_f9b4a_row22_col20, #T_f9b4a_row22_col28, #T_f9b4a_row24_col3, #T_f9b4a_row24_col4, #T_f9b4a_ro

# %%
px.bar(corr_df, x='Malc')

# %%
# 상관계수를 절대값을 해준 후 데이터 프레임 만들기
abs_df = corr_df.Malc.abs().to_frame('corr_score').corr_score.nlargest(31).to_frame('score')

# %% [markdown]
# - 음의 상관관계도 포함

# %%
abs_df.reset_index(inplace=True)

# %%
choice_col_list_df = abs_df.head(17)

# %%
choice_col_list_df
# Out:
#          index  score
# 0         Malc   1.00
# 1        goout   0.37
# 2          sex   0.32
# 3    studytime   0.22
# 4       Agrade   0.15
# 5     absences   0.15
# 6     freetime   0.15
# 7         Fjob   0.13
# 8       reason   0.13
# 9          age   0.12
# 10    failures   0.12
# 11      higher   0.11
# 12  traveltime   0.10
# 13      famrel   0.10
# 14      health   0.10
# 15     famsize   0.09
# 16     nursery   0.09

# %% [markdown]
# ---

# %% [markdown]
# ### 최종 상관계수

# %%
Malc_df = corr_df[['Malc']]

# %%
Malc_df.reset_index(inplace=True)

# %%
pos_14_corr_df = Malc_df.head(14)

# %%
neg_4_corr_df = Malc_df.tail(3)

# %%
most_corr_df= pd.concat([pos_14_corr_df, neg_4_corr_df],axis=0)

# %%
most_corr_df.columns = ['features', 'score']

# %%
most_corr_df.reset_index(inplace=True)

# %%
most_corr_df.drop('index', inplace=True, axis=1)

# %%
most_corr_df
# Out:
#       features  score
# 0         Malc   1.00
# 1        goout   0.37
# 2          sex   0.32
# 3     absences   0.15
# 4     freetime   0.15
# 5         Fjob   0.13
# 6       reason   0.13
# 7          age   0.12
# 8     failures   0.12
# 9       higher   0.11
# 10  traveltime   0.10
# 11      health   0.10
# 12     famsize   0.09
# 13     nursery   0.09
# 14      famrel  -0.10
# 15      Agrade  -0.15
# 16   studytime  -0.22

# %% [markdown]
# ---

# %% [markdown]
# #### 일 소비량과 주말 소비량을 합쳐서 본 히트맵
# 학업에서 성공하는 비결은 술??????
# - 술 마시면 자신감이 배가 되어 시험을 잘 본다는 것이 학계의 정설!!
#
#
#
# - 술을 마신다고 해서 성적과 연관이 있을까? -> 결과적으로 술을 마시는 행위 자체가 일탈이라고 볼 수 있을까? -> 성적이 높다고 하여 모범생??????
# - 부모님의 교육 여부에 따라 술 소비량이 달라질까?
# - 나이가 많다고 해서 술을 많이 마실까?
# - 학교별로 나누어서 술 소비량이 성적에 미치는 것을 구별해야 할까?
# - 그럼 술을 많이 마시게 되는 요인이 무엇이 될까?
#   - 학교 환경
#   - 나가서 놀기
#   - 나이
#   - 부모님의 교육상태
#   - 여가시간
#   - 공부시간???
#   - 건강
#   - 결석
#   - 성적?
#   - 과목? 근데 수학을 선택했다면 누칼협아님?

# %% [markdown]
# - 용정 : 'failures', 'freetime', 'Fjob', AGrade
# - 종호 : 'studytime', 'sex', 'age', 'reason'
# - 정원 : 'goout', famrel, 'absences', 'health'

# %% [markdown]
# - Medu, famrel, AGrade, studytime

# %% [markdown]
# ## 범주형 변수 수치형변수로 변환하기

# %%
def init_mapping(data, col_ls):
    """_summary_

    Args:
        data (DataFrame): 변환하고자 하는 데이터 프레임
        col_name (list): 변환하고 하자는 데이터 프레임의 컬럼명을 리스트로 input
    """
    print('Start Mapping.......')
    print('-' * 50)
    for i in range(len(col_ls)):
        data_ls = data[col_ls[i]].unique()
        print('column name :', col_ls[i])
        num = []
        if len(data_ls) == 2:
            num = [i for i in range(len(data_ls))] # 번호 생성
        else:
            num = [i + 1 for i in range(len(data_ls))]
        ls = [(data_ls[i], num[i]) for i in range(len(data_ls))] # 해당 컬럼의 데이터 와 번호 리스트로 생성
        print(ls)
        mapping = dict(ls) # dict로 만듬
        data[col_ls[i]] = data[col_ls[i]].apply(lambda x: mapping[x]) # mapping 적용

# %%
concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044 entries, 0 to 1043
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        1044 non-null   object
#  18  activities  1044 non-null   object
#  19  nursery     1044 non-null   object
#  20  higher      1044 non-null   object
#  21  internet    1044 non-null   object
#  22  romantic    1044 non-null   object
#  23  famrel      1044 non-null   int64
#  24  freetime    1044 non-null   int64
#  25  goout       1044 non-null   int64
#  26  health      1044 non-null   int64
#  27  absences    1044 non-null   int64
#  28  subject     1044 non-null   object
#  29  Malc        1044 non-null   float64
#  30  Agrade      1044 non-null   float64
# dtypes: float64(2), int64(11), object(18)
# memory usage: 253.0+ KB

# %%
# Fjob은 unique의 순서가 달라 따로 맵핑함
mapping = {
    'at_home' : 1,
    'health' : 2,
    'other' : 3, 
    'services': 4,
    'teacher' : 5
}
concat_df['Fjob'] = concat_df['Fjob'].apply(lambda x: mapping[x])

# %%
mapping = {
    'yes' : 1,
    'no' :0
}
concat_df['schoolsup'] = concat_df['schoolsup'].apply(lambda x: mapping[x])
concat_df['nursery'] = concat_df['nursery'].apply(lambda x: mapping[x])
concat_df['higher'] = concat_df['higher'].apply(lambda x: mapping[x])

# %%
col_ls = [
    'school', 'sex', 'address', 'famsize', 
    'Pstatus', 'Mjob', 'reason', 'guardian', 
    'famsup', 'paid', 'activities', 'internet', 
    'romantic', 'subject'
    ]

# %%
init_mapping(concat_df, col_ls)
# Out:
# Start Mapping.......
# --------------------------------------------------
# column name : school
# [('GP', 0), ('MS', 1)]
# column name : sex
# [('F', 0), ('M', 1)]
# column name : address
# [('U', 0), ('R', 1)]
# column name : famsize
# [('GT3', 0), ('LE3', 1)]
# column name : Pstatus
# [('A', 0), ('T', 1)]
# column name : Mjob
# [('at_home', 1), ('health', 2), ('other', 3), ('services', 4), ('teacher', 5)]
# column name : reason
# [('course', 1), ('other', 2), ('home', 3), ('reputation', 4)]
# column name : guardian
# [('mother', 1), ('father', 2), ('other', 3)]
# column name : famsup
# [('no', 0), ('yes', 1)]
# column name : paid
# [('no', 0), ('yes', 1)]
# column name : activities
# [('no', 0), ('yes', 1)]
# column name : internet
# [('no', 0), ('yes', 1)]
# column name : romantic
# [('no', 0), ('yes', 1)]
# column name : subject
# [('M', 0), ('P', 1)]

# %%
concat_df.head(10)
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0       0    0   18        0        0        0     4     4     1     5
# 1       0    0   17        0        0        1     1     1     1     3
# 2       0    0   15        0        1        1     1     1     1     3
# 3       0    0   15        0        0        1     4     2     2     4
# 4       0    0   16        0        0        1     3     3     3     3
# 5       0    1   16        0        1        1     4     3     4     3
# 6       0    1   16        0        1        1     2     2     3     3
# 7       0    0   17        0        0        0     4     4     3     5
# 8       0    1   15        0        1        0     3     2     4     3
# 9       0    1   15        0        0        1     3     4     3     3
#
#    reason  guardian  traveltime  studytime  failures  schoolsup  famsup  paid  \
# 0       1         1           2          2         0          1       0     0
# 1       1         2           1          2         0          0       1     0
# 2       2         1           1          2         3          1       0     1
# 3       3         1           1          3         0          0       1     1
# 4       3         2           1          2         0          0       1     1
# 5       4         1           1          2         0          0       1     1
# 6       3         1           1          2         0          0       0     0
# 7       3         1           2          2         0          1       1     0
# 8       3         1           1          2         0          0       1     1
# 9       3         1           1          2         0          0       1     1
#
#    activities  nursery  higher  internet  romantic  famrel  freetime  goout  \
# 0           0        1       1         0         0       4         3      4
# 1           0        0       1         1         0       5         3      3
# 2           0        1       1         1         0       4         3      2
# 3           1        1       1         1         1       3         2      2
# 4           0        1       1         0         0       4         3      2
# 5           1        1       1         1         0       5         4      2
# 6           0        1       1         1         0       4         4      4
# 7           0        1       1         0         0       4         1      4
# 8           0        1       1         1         0       4         2      2
# 9           1        1       1         1         0       5         5      1
#
#    health  absences  subject  Malc  Agrade
# 0       3         6        0  1.00    5.67
# 1       3         4        0  1.00    5.33
# 2       3        10        0  2.50    8.33
# 3       5         2        0  1.00   14.67
# 4       5         4        0  1.50    8.67
# 5       5        10        0  1.50   15.00
# 6       3         0        0  1.00   11.67
# 7       1         6        0  1.00    5.67
# 8       1         0        0  1.00   17.67
# 9       5         0        0  1.00   14.67

# %%
concat_df.to_csv('~/desktop/git/hakcerton/data/preprocessing/final_data.csv', index=False)

# %% [markdown]
# ------------------------------------------------------------------------------------------------

# %%
#필요데이터: 
    # Dalc
    # Walc
    # Malc 우선 이거부터

    # studytime
    # sex
    # age
    # reason

df_new = concat_df.iloc[:,[1,2,10,13,29]]
df_new.head(-10)
# Out:
#       sex  age  reason  studytime  Malc
# 0       0   18       1          2  1.00
# 1       0   17       1          2  1.00
# 2       0   15       2          2  2.50
# 3       0   15       3          3  1.00
# 4       0   16       3          2  1.50
# ...   ...  ...     ...        ...   ...
# 1029    0   18       3          2  1.50
# 1030    0   17       4          2  2.50
# 1031    1   18       3          2  2.50
# 1032    1   18       2          1  2.00
# 1033    1   17       3          2  1.00
#
# [1034 rows x 5 columns]

# %% [markdown]
# -------------

# %% [markdown]
# # 기본정보 시각화
#
# - 성별 수
# - 나이 수
# - 공부시간
# - 학교 다니는 이유

# %% [markdown]
# ### 1. 성별 수

# %%
concat_df_sex
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         3       yes     no  yes
# 3      home   mother           1          3         0        no    yes  yes
# 4      home   father           1          2         0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2  G3 subject  Malc
# 0       1     1       3         6   5   6   6       M  1.00
# 1       1     1       3         4   5   5   6       M  1.00
# 2       2     3       3        10   7   8  10       M  2.50
# 3       1     1       5         2  15  14  15       M  1.00
# 4       1     2       5         4   6  10  10       M  1.50
# ..    ...   ...     ...       ...  ..  ..  ..     ...   ...
# 644     1     2       5         4  10  11  10       P  1.50
# 645     1     1       1         4  15  15  16       P  1.00
# 646     1     1       5         6  11  12   9       P  1.00
# 647     3     4       2         6  10  10  10       P  3.50
# 648     3     4       5         4  10  11  11       P  3.50
#
# [1044 rows x 35 columns]

# %%
plt.figure(figsize = (22,22))
plt.subplot(221)
data = concat_df_sex
labels = 'sex'
colors = sns.color_palette('Set1')[0:5]
palette='Set1'
total = concat_df_sex['sex'].value_counts().values.sum()

def fmt(x):
    return '{:.1f}%\n{:.0f}'.format(x, total*x/100)

plt.title('Gender Distribution', size=15)
plt.pie(concat_df_sex['sex'].value_counts().values, labels=concat_df_sex['sex'].value_counts().index, autopct=fmt)


plt.subplot(222)
sns.distplot(df_new['age'], label='age')
plt.legend(loc='upper right', fontsize=15)
plt.title('Age', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('age', fontsize=15)
plt.ylabel('Count', rotation=0, fontsize=15)


plt.figure(figsize = (25,10))
plt.subplot(223)
sns.countplot(x = 'age', hue = 'sex',data=concat_df_sex, palette='Set1')
plt.title('age', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('age', fontsize=15)

plt.show()

# 0 과1 대신 성별을 넣는방법은?

# %% [markdown]
# ### 참여자 조사
#
# 조사에 참여한 학생은 총 1,044명으로 여학생 56.6% (숫자 0), 남학생 43.4% (숫자 1)로 여학생 참여자가 남학생 참여자보다 많았다.
# 참여자들은 모두 15세에서 22세 사이의 연령대였으며 모든 성별에서 16세에서 17세 사이에 가장 큰 분포를 보이고 있다.

# %% [markdown]
# ### - Studytime & Reason

# %%
plt.figure(figsize = (15,25))

plt.subplot(221)
data = df_new
labels = 'studytime'
# colors = sns.color_palette('bright')[0:5]
total = df_new['studytime'].value_counts().values.sum()

def fmt(x):
    return '{:.1f}%\n{:.0f}'.format(x, total*x/100)

plt.title('Studytime ratio', size=15)
plt.pie(df_new['studytime'].value_counts().values, labels=df_new['studytime'].value_counts().index, autopct=fmt)


plt.subplot(222)
data = df_new
labels = 'reason'
# colors = sns.color_palette('bright')[0:5]
total = df_new['reason'].value_counts().values.sum()

def fmt(x):
    return '{:.1f}%\n{:.0f}'.format(x, total*x/100)

plt.title('reason', size=15)
plt.pie(df_new['reason'].value_counts().values, labels=df_new['reason'].value_counts().index, autopct=fmt)

plt.figure(figsize = (15,7))
plt.subplot(223)
sns.distplot(df_new['studytime'], label='age')
plt.legend(loc='upper right', fontsize=15)
plt.title('studytime', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('studytime', fontsize=15)
plt.ylabel('Count', rotation=0, fontsize=15)

plt.show()

# 두개 색깔 같게 하려면?

# %% [markdown]
# 공부시간 :
# - 1 - <2 hours,
# - 2 - 2 to 5 hours,
# - 3 - 5 to 10 hours
# - 4 - >10 hours
# <br/>
#
# 학교를 다니는 이유:
# - 'course' -  1
# - 'other' -  2
# - 'home' -  3
# - 'reputation' -  4
#
# <br/>
#
#
#
# 설문조사에 따르면 전체 학생중 공부시간은 2~5시간하는 학생이 약 48.2%로 가장 높은 비율을 보였으며 그다음은 2시간 미만 30.4%, 5~10시간 15.5%, 그리고 10시간 이상 5.9% 순으로 비율이 높았다.
#
# 현재 다니고 있는 학교를 선택한 이유에 대해서 가장 높은 비율인 41.2%의 학생이 특정 과목 선호(1)로 가장 높은 비율을 보였으며 그다음으론 집에서 가까운 이유와 학교의 명성이 각각 24.7%와 23.8%로 비슷한 반응을 보였고 마지막으로 기타이유가 10.3%의 반응을 보였다

# %% [markdown]
# # 데이터 상관관계 분석

# %% [markdown]
# ## Point 1) 공부시간과 음주량의 상관관계

# %% [markdown]
# 위 데이터 분석을 통해 전체 음주 빈도와 공부시간은 서로 음의 상관계수 (-0.22)를 보이고있다.
# </br>
# 즉 공부 시간이 줄어들수록 음주 빈도수가 늘어나며 공부 시간이 늘어날수록 음주 빈도수가 줄어든다고 가정해 볼 수 있다.
# </br>
# 좀 더 자세하고 시각적인 정보 분석을 위해서 그래프로 나타내보았다.

# %% [markdown]
# ### 1. 공부시간 - 음주빈도수
# - 상관계수: -0.22

# %%
plt.figure(figsize = (15,15))

# plt.subplot(221)
# sns.barplot(x='studytime', y='Malc', data=df_new, palette='Set1')
# plt.title('Studytime & Malc', size=15)
# plt.xticks(fontsize=15)
# plt.yticks(fontsize=15)
# plt.xlabel('studytime', fontsize=15)
# plt.ylabel('Malc', fontsize=15)

plt.subplot(221)
sns.boxplot(x = 'studytime', y = 'Malc',data=df_new,
            palette='Set1')
plt.title('studytime', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('studytime', fontsize=15)
plt.ylabel('Malc', fontsize=15)

plt.subplot(222)
sns.countplot(data=concat_df, x='studytime', hue='Malc', palette='Set1')
plt.legend(loc='upper right', title='Malc', fontsize=15)
plt.title('studytime', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('studytime', fontsize=15)
plt.ylabel('Count',  fontsize=15)

plt.figure(figsize = (40,15))
plt.subplot(223)
sns.distplot(df_new['studytime'], label='studytime')
sns.distplot(df_new['Malc'], label = ['Malc'])
plt.legend(loc='upper right', fontsize=15)
plt.title('Sex & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Studytime & Malc', fontsize=15)
plt.ylabel('Count', rotation=0, fontsize=15)


plt.show()

# %% [markdown]
# <br/>
# 위 그래프에서 확인해본 결과 공부시간이 적을수록 더 많은 전체 음주량을 보이고 있음이 확인되었다. 특히 공부시간이 올라갈 수록 몇몇 예외의 케이스를 제외하곤 전체적으로 음주량이 올라가는것을 확인할 수 있었다.
#
# 특히 4~5의 많은 음주량을 보이는 학생 대다수의 학습시간은 1~2, 즉 0~5시간 사이의 학습시간을 가지고 있음이 나타났다.

# %% [markdown]
# ### Details

# %%
plt.figure(figsize = (15,15))
plt.subplot(221)
sns.barplot(data=concat_df_sex, x='studytime',y='Malc' , hue='sex', palette='Set1')
plt.legend(loc='upper right', fontsize=15)
plt.title('Study & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('studytime', fontsize=15)
plt.ylabel('Malc', rotation=0, fontsize=15)


plt.subplot(222)
sns.lineplot(data=concat_df_sex, x='studytime',y='Malc' , hue='sex', palette='Set1')
plt.title('Age & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('studytime', fontsize=15)
plt.ylabel('Malc', rotation=0, fontsize=15)


plt.show()

# %% [markdown]
# <br/>
#
# 1. 좀 더 자세한 분석으로 성별을 나누어서 학습시간과 음주량을 분석해보았을때, 남성이 전반적으로 여성보다 더 많은 학습시간과 음주량을 가지고 있다는것이 확인되었다.
#
# 2. 여성은 학습시간이 늘어날수록 음주량이 점진적으로 감소하지만, 남성의 경우 학습시간이 늘어남에 따라 음주량이 점진적으로 감소하다가 학습레벨4 (10시간 이상 학습)에 도달했을때 급격한 상승을 보여주었다.

# %% [markdown]
# ### 2. 성별 - 음주 빈도수
# - 상관계수 0.32

# %%
plt.figure(figsize = (15,15))

plt.subplot(221)
sns.barplot(x='sex', y='Malc', data=concat_df_sex, palette='Set1')
plt.title('Sex & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('sex', fontsize=15)
plt.ylabel('Malc', fontsize=15)

plt.subplot(222)
sns.boxplot(x='sex', y='Malc',data=concat_df_sex,
            palette='Set1')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('sex', fontsize=15)
plt.ylabel('Malc', fontsize=15)

plt.figure(figsize = (25,15)) 
plt.subplot(223)
sns.countplot(data=concat_df_sex, x='Malc', hue='sex', palette='Set1')
plt.title('Age & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Malc', fontsize=15)
plt.ylabel('Count', fontsize=15)



plt.show()

# %% [markdown]
# - 0: 여성
# - 1: 남성
# <br/>
#
# 성별에 따른 음주량에 대한 상관계수는 0.32의 상관관계를 보이고있다.
#
# 위 그래프 분석에 따르면 여성에 비해서 남성이 더 높은 수치의 음주량을 보이고 있다는것이 보여진다.
#
# 여성은 낮은 음주량에서 더 높은 비율을 보이고 있으며 음주량이 올라갈수록 급격한 감소세를 보이고있다.
#
# 반면 남성의 음주량 경우, 점진적인 감소세를 보이고 있으며 3 level의 음주량부터는 남성이 여성보다 더 높은 비율을 가지고 간다

# %% [markdown]
# ### 3. 나이 - 음주 빈도수
# - 상관계수: 0.12

# %%
plt.figure(figsize = (15,15))

plt.subplot(221)
sns.barplot(x='age', y='Malc', data=df_new, palette='Set1')
plt.title('Age & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('age', fontsize=15)
plt.ylabel('Malc', fontsize=15)

plt.subplot(222)
sns.boxplot(x='age', y='Malc',data=df_new,
            palette='Set1')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('age', fontsize=15)
plt.ylabel('Malc', fontsize=15)

plt.show()

# %% [markdown]
# <br/>
# 상관계수 0.12가 가리키듯 22살때를 제외하곤 나이에 따른 술 섭취량에 큰 변화가 보이지 않는다.

# %% [markdown]
# ### Details

# %%
plt.figure(figsize = (15,15))

plt.subplot(221)
sns.boxplot(data=concat_df_sex, x='age',y='Malc' , hue='sex', palette='Set1')
plt.legend(loc='upper right', fontsize=15)
plt.title('Age & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('age', fontsize=13)
plt.ylabel('Malc', rotation=0, fontsize=13)


plt.subplot(222)
sns.countplot(data=concat_df_sex, x='Malc', hue='sex', palette='Set1')
plt.legend(loc='upper right', fontsize=15)
plt.title('Age & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Malc', fontsize=13)
plt.ylabel('Count', rotation=0, fontsize=13)

plt.subplot(223)
sns.barplot(data=concat_df_sex, x='age',y='Malc' , hue='sex', palette='Set1')
plt.legend(loc='upper left', fontsize=15)
plt.title('Age & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('age', fontsize=13)
plt.ylabel('Malc', rotation=0, fontsize=13)


plt.subplot(224)
sns.lineplot(data=concat_df_sex, x='age',y='Malc' , hue='sex', palette='Set1')
plt.title('Age & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('age', fontsize=13)
plt.ylabel('Malc', rotation=0, fontsize=13)

plt.show()

# %% [markdown]
# <br/>
#
# 1. 남성은 전연령대에 걸쳐 여성보다 높은 음주량을 보이고 있다.
#
# 2. 여성의 경우 15~20세 사이엔 음주량에 큰변확가 없다가 21살 이후부턴 급격하게 감소하며 22세 이후부턴 음주량이 보이지 않는다.
#
# 3. 반면 남성의 경우 19세 이후부턴 음주량이 급격한 상승세를 보이고있다.

# %% [markdown]
# ### 4. 특정학교를 선택한 이유와 음주빈도
# - 상관관계 0.13

# %%
plt.figure(figsize = (15,15))

plt.subplot(221)
sns.barplot(x='reason', y='Malc', data=df_new, palette='Set1')
plt.title('Reason & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('reason', fontsize=15)
plt.ylabel('Malc', fontsize=15)

plt.subplot(222)
sns.boxplot(data=concat_df, x='reason',y='Malc', palette='Set1')
plt.title('Reason & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('reason', fontsize=15)
plt.ylabel('Malc', rotation=0, fontsize=15)

plt.show()

# %% [markdown]
# <br/>
#
# Reason (특정 학교를 선택한 이유)
#
# 1 : Course (선호 과목)
#
# 2 : Other (기타)
#
# 3 : Home (집에서 가까운거리)
#
# 4 : Reputation (학교 명성)
#
#
# 특정 학교를 선택한 이유와 음주량의 상관관계를 들여다 봤을때 (상관계수 0.13) 기타의 항목을 고른 학생들의 음주량이 다른 선택지를 고른 학생들보다 많았음이 나타났지만 특별히 상관관계가 있다는 단서가 보이진 않는다.

# %%
plt.figure(figsize = (15,15))
plt.subplot(221)
sns.barplot(data=concat_df_sex, x='reason',y='Malc' , hue='sex', palette='Set1')
plt.legend(loc='upper right', fontsize=15)
plt.title('reason & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('reason', fontsize=15)
plt.ylabel('Malc', rotation=0, fontsize=15)


plt.subplot(222)
sns.boxplot(data=concat_df_sex, x='reason',y='Malc' , hue='sex', palette='Set1')
plt.legend(loc='upper right', fontsize=15)
plt.title('Age & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('reason', fontsize=15)
plt.ylabel('Malc', rotation=0, fontsize=15)
plt.show()

# %% [markdown]
# ### Details

# %%
plt.figure(figsize = (15,15))

plt.subplot(221)
sns.barplot(x='reason', y='studytime', data=df_new, palette='Set1')
plt.title('Reason & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('reason', fontsize=15)
plt.ylabel('studytime', fontsize=15)


plt.subplot(222)
sns.boxplot(data=concat_df, x='reason',y='studytime', palette='Set1')
plt.title('Reason & Malc', size=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('reason', fontsize=15)
plt.ylabel('studytime', fontsize=15)

plt.show()

# %% [markdown]
# <br/>
#
# 특정 학교를 선택한 이유와 학습시간은 0.2의 상관계수를 지닌다.
#
# 이 상관관계를 그래프로 표현했을때, 유일하게 학교를 선택한 이유에 "학교 명성" 을 선택한 학생들이 다른 이유를 가지고 있는 학생들보다 더 높은 학습시간을 가져갔다.
#
# 허나 위에 데이터에서 나왔다시피 특정학교를 선택한 이유와 음주량은 0.13의 상관계수를 띄기에 상관관계가 있다고 말하기 어렵다.

# %% [markdown]
# # Conclusion

# %% [markdown]
# <br/>
#
#
#
# 1. 공부시간 - 음주량 : 음의 상관계수 (-0.22)가 가리키듯이 몇몇의 예외 케이스를 제외하곤 공부시간이 적을수록 더 많은 음주량을 보인다는게 확인되었다. 특히 가장 많은 음주량인 4~5 level의 학생들의 대부분 학습시간은 1~2 level인 0~5시간의 학습시간을 가지고 있음이 확인되었으며 그 이상의 학습시간을 가지는 학생일수록 음주량이 감소한다는것 또한 확인되었다.
#     추가적인 정보로 성별을 더했을때 남성이 여성보다 전반적으로 더 많은 학습시간과 음주량을 가지고 있다는것이 확인 되었으며 여성 남성 모두 공통적으로 학습시간이 늘어날수록 음주량이 감소하지만 예외적으로 학습레벨이 가장 높은 단계인 4에 도달할 때 남성의 음주량이 금격한 상승세를 보이는것이 확인 되었다.
#
#
# <br/>
#
#
#
#
# 2. 성별 - 음주량 : 성별에 따른 상관계수는 0.32로 성별과 음주량이 어느정도의 상관관계를 가지고 있음이 확인되었다. 위에 서술되있듯이 남성이 여성에 비해 더 높은 음주량을 보여주고 있으며 음주량에 대하여 여성이 낮은 음주량에서 더 높은 비율을 보이고 있고 음주량이 올라갈수록 급격한 감소세를 보이고있다. 반면 남성 음주량의 경우, 전반적으로 감소세를 보이다가 level 3의 음주량부터는 남성이 여성의 음주량을 추월하는것이 확인되었다.
#
# <br/>
#
#
#
# 3. 연령 - 음주량 : 연령과 음주량의 상관계수는 0.12로 뚜렷한 상관관계를 보이지 않고있다. 단지 자세한 분석을 통하여 여성의 경우 15~20세 사이엔 음주량에 큰 변화가 없다가 그 이후부턴 급격하게 감소세를 보이고 있고 남성의 경우엔 19세부터 음주량이 급격하게 상승하여 남성과 여성이 19~20세 연령대에서 반비례한 음주량을 기록한다는것이 확인되었다.
#
# <br/>
#
#
#
# 4. 특정 학교를 선택한 이유 - 음주량 : 학습시간과 특정 학교를 선택한 이유의 상관관계가 0.2가 나온 반면에 학생이 특정 학교를 선택한 이유와 음주량의 상관계수는 0.13으로  특별한 상관관계를 보이지 않고있다. 단지 자세한 분석을 진행하였을때, 유일하게 특정 학교를 선택한 이유가 "학교의 명성" 인 학생들만 더 높은 학습시간을 가져간것을 나타났지만 특정 학교를 선택한 이유와 음주량의 관계가 보인다고 말하기는 어렵다.
